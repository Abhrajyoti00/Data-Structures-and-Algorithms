# %% [markdown]
# # Reversing a Stack using an extra empty stack and recursion

# %%
from sys import stdin, setrecursionlimit
setrecursionlimit(10 ** 6)


def reverseStack(inputStack, extraStack) :
    if len(inputStack) <= 1:
        return
    while len(inputStack)>1:
        extraStack.append(inputStack.pop())
    ele = inputStack.pop()
    while len(extraStack)!=0:
        inputStack.append(extraStack.pop())
    reverseStack(inputStack, extraStack)
    inputStack.append(ele)






























'''-------------- Utility Functions --------------'''

#Taking input using fast I/o method
def takeInput() :
	size = int(stdin.readline().strip())
	inputStack = list()

	if size == 0 :
		return inputStack


	values = list(map(int, stdin.readline().strip().split(" ")))
	inputStack = values

	return inputStack


#main
inputStack = takeInput()
emptyStack = list()

reverseStack(inputStack, emptyStack)

while len(inputStack)!=0 :
	print(inputStack.pop(), end = " ")
