# %% [markdown]
# ## The following code in DFS is correct, but it's geetting TLE because of Slow Python

# %%
import queue

class Graph:
    def __init__(self, nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for j in range(nVertices)] for i in range(nVertices)]

    def addEdge(self, v1,v2):
    
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1
    

    def dfs(self,sv,visited):
        # visited = [False for i in range(self.nVertices)]
        visited[sv] = True

        for i in range(self.nVertices):
            if ((self.adjMatrix[sv][i] > 0) and (visited[i] is False)):  # Not visited and edge is present:
                self.dfs(i, visited)

        # return visited



    
        
ve = list(map(int,input().split()))
v = ve[0]
e = ve[1]
g = Graph(v)   # Extra One to avoid conflicts
for i in range(e):
    v1v2 = list(map(int,input().split()))
    v1 = v1v2[0]
    v2 = v1v2[1]
    g.addEdge(v1,v2)

visited = [False for i in range(v)]

if v>0:
    g.dfs(0,visited)
    if False in visited:
        print('false')
    else:
        print('true')
else:
    print('true')

# %% [markdown]
# ## Since BFS is faster than DFS, this is correct

# %%
import queue

class Graph:
    def __init__(self, nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for j in range(nVertices)] for i in range(nVertices)]

    def addEdge(self, v1,v2):
    
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1
    
    def removeEdge(self, v1, v2):
        if self.containsEdge(v1,v2) is False:
            return
        self.adjMatrix[v1][v2] = 0
        self.adjMatrix[v2][v1] = 0

    def containsEdge(self, v1, v2):
        return True if self.adjMatrix[v1][v2]>0 and self.adjMatrix[v2][v1] > 0 else False

    def __str__(self):
        return str(self.adjMatrix)


    def __dfsHelper(self, sv, visited):
        print(sv)
        visited[sv] = True

        for i in range(self.nVertices):
            if self.adjMatrix[sv][i] > 0 and visited[i] is False:  # Not visited and edge is present:
                self.__dfsHelper(i, visited)

    def dfs(self):
        visited = [False for i in range(self.nVertices)]
        self.__dfsHelper(0,visited)


    def __bfs (self, sv, visited):
        q = queue.Queue()
        q.put(sv)
        visited[sv] = True
        while q.empty() is False :
            u = q.get()
            # print(u, end= " " )
            for i in range(self.nVertices) :
                if self.adjMatrix[u][i] > 0 and visited[i] is False :
                    q.put(i)
                    visited[i] = True
        return visited
    def bfs (self):
        visited = [ False for i in range(self.nVertices)]
        self.__bfs(0, visited)
        return visited


ve = list(map(int,input().split()))
v = ve[0]
e = ve[1]
g = Graph(v)
for i in range(e):
    v1v2 = list(map(int,input().split()))
    v1 = v1v2[0]
    v2 = v1v2[1]
    g.addEdge(v1,v2)

if v>0:
    visited = g.bfs()
    if False in visited:
        print('false')
    else:
        print('true')
else:
    print('true')
